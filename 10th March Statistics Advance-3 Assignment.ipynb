# %%
#Statistics Advance-3 Assignment
"""Q1: What is Estimation Statistics? Explain point estimate and interval estimate."""
Ans: Estimation statistics is a branch of statistics that deals with the estimation of population parameters
from sample data. Estimation involves the use of point estimates and interval estimates. 

A point estimate is a single value that is used to estimate a population parameter. It is usually the 
sample statistic, such as the sample mean or sample proportion, that is used to estimate the population 
parameter. 

An interval estimate is a range of values that is used to estimate a population parameter. It is usually 
constructed using the sample statistic and some measure of its variability, such as the standard error or 
confidence interval. The interval estimate provides a range of values that is likely to contain the population 
parameter.

"""Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation."""
Ans: 
def population_mean(sample_mean, sample_std):
population_mean = sample_mean + (sample_std / (len(sample) ** 0.5))
return population_mean 

#example
sample = [1,2,3,4,5]
sample_mean = sum(sample) / len(sample)
sample_std = (sum([(x - sample_mean) ** 2 for x in sample]) / len(sample)) ** 0.5

population_mean = population_mean(sample_mean, sample_std)
print(population_mean)

"""Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing."""
Ans: Hypothesis testing is a statistical method used to test a hypothesis about a population parameter. 
It is used to determine whether the hypothesis is true or false. The importance of hypothesis testing 
lies in its ability to help researchers make decisions and draw conclusions based on data. Hypothesis 
testing allows researchers to make decisions about the validity of their research and to draw conclusions
about the population from which the sample was taken. It also helps researchers identify relationships 
between variables and determine if a relationship is statistically significant. Hypothesis testing is an
important tool for making decisions in research, as it allows researchers to make informed decisions based
on data.

"""Q4. Create a hypothesis that states whether the average weight of male college students is greater than
the average weight of female college students."""
Ans: Hypothesis: The average weight of male college students is greater than the average weight of female 
college students.

"""Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
given a sample from each population."""
Ans: 
#import necessary libraries
import numpy as np
from scipy import stats

#define the two populations and their sample sizes 
population_1 = [1,2,3,4,5] 
population_2 = [6,7,8,9,10]
sample_size_1 = 3
sample_size_2 = 3

#calculate the means of the two populations 
mean_1 = np.mean(population_1) 
mean_2 = np.mean(population_2) means of the two populations 
mean_1 = np.mean(population_1) 
mean_2 = np.mean(population_2)

#calculate the difference between the two population means 
difference = mean_1 - mean_2

#generate random samples from each population 
sample_1 = np.random.choice(population_1, sample_size_1) 
sample_2 = np.random.choice(population_2, sample_size_2)

#calculate the means of the two samples 
sample_mean_1 = np.mean(sample_1) 
sample_mean_2 = np.mean(sample_2)

#calculate the difference between the two sample means 
sample_difference = sample_mean_1 - sample_mean_2

#conduct a t-test to determine if the difference between the two population means is statistically significant 
t, p = stats.ttest_ind(sample_1, sample_2)

#print the results 
print("The t-statistic is %.3f and the p-value is %.3f." % (t, p))

if p < 0.05:
    print("The difference between the two population means is statistically significant.")
else:
    print("The difference between the two population means is not statistically significant.")
    
"""Q6: What is a null and alternative hypothesis? Give some examples."""
Ans: A null hypothesis is a statement that suggests that there is no relationship between two variables. An alternative 
hypothesis is a statement that suggests that there is a relationship between two variables. 

Examples: 
Null Hypothesis: There is no difference in the average test scores of students who study for two hours and those who 
study for four hours. 
Alternative Hypothesis: There is a difference in the average test scores of students who study for two hours and those 
who study for four hours.

"""Q7: Write down the steps involved in hypothesis testing."""
Ans: 
1. State the null and alternative hypotheses.
2. Select a significance level (α).
3. Calculate the test statistic and its associated p-value.
4. Make a decision about the null hypothesis based on the p-value and significance level.
5. Interpret the results in terms of the problem.

"""Q8. Define p-value and explain its significance in hypothesis testing."""
Ans: The p-value is a measure of the probability that the observed results in a hypothesis test are due to chance. It is
used to determine whether or not to reject the null hypothesis. If the p-value is less than the significance level 
(usually 0.05), then the null hypothesis is rejected and the alternative hypothesis is accepted. The smaller the p-value,
the stronger the evidence against the null hypothesis.

"""Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
parameter set to 10."""
Ans: 
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t

# Set degrees of freedom parameter to 10
df = 10 

# Generate x-axis values from -3 to 3 with 500 points in between
x = np.linspace(-3, 3, 500)

# Generate the corresponding y-axis values for t-distribution with df=10
y = t.pdf(x, df)

# Plot the t-distribution curve 
plt.plot(x, y)

# Label the axes
plt.xlabel('x')
plt.ylabel('t(x)')

# Show the plot
plt.show()

"""Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of 
equal size and a null hypothesis that the population means are equal."""
Ans: 
# Importing the necessary libraries 
import numpy as np 
from scipy import stats 
  
# Defining the two samples 
sample1 = np.array([1,2,3,4,5]) 
sample2 = np.array([2,3,4,5,6]) 
  
# Calculating the two-sample t-test for independent samples 
t_statistic, p_value = stats.ttest_ind(sample1, sample2) 
  
# Printing the results 
print("T-statistic =", t_statistic) 
print("P-value =", p_value) 
  
# Interpreting the results 
if p_value < 0.05: 
    print("Reject the null hypothesis") 
else: 
    print("Fail to reject the null hypothesis")

"""Q11: What is Student’s t distribution? When to use the t-Distribution."""
Ans: 
Student’s t distribution is a type of probability distribution that is used when the sample size is small and the 
population standard deviation is unknown. It is used in hypothesis testing to compare the means of two samples when 
the variances of the two populations are unknown or when the sample size is small. It is also used in confidence 
intervals to estimate the population mean when the population standard deviation is unknown.

"""Q12: What is t-statistic? State the formula for t-statistic."""
Ans: A t-statistic is a type of statistical measure used to compare the means of two samples. It is calculated by taking
the difference between two sample means and dividing it by the standard error of the difference between the two sample 
means. The formula for t-statistic is: 

t-statistic = (x1 - x2) / SE(x1 - x2)

where x1 and x2 are the sample means and SE(x1 - x2) is the standard error of the difference between the two sample means.

"""Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
Estimate the population mean revenue with a 95% confidence interval."""
Ans: $500 ± $25

"""Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05."""
Ans: 
H0: μ = 5
H1: μ < 5

Test Statistic: Z = (x̅ - μ) / (σ/√n) 
              = (4.8 - 5) / (0.5/√25) 
              = -2.8

Critical Value: Zα = -2.33 (for α = 0.01)

Since the test statistic (Z = -2.8) is less than the critical value (Zα = -2.33), we reject the null hypothesis and 
conclude that the true mean weight of the products is less than 5 pounds.

"""Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
groups are equal with a significance level of 0.01."""
Ans: 
H0: μ1 = μ2
H1: μ1 ≠ μ2

Test Statistic:  Z = (80 - 75) / (√(10^2/30 + 8^2/40)) = 1.25

Critical Value: Zα/2 = 2.33

Since 1.25 < 2.33, we fail to reject the null hypothesis and conclude that the population means for the two groups are 
equal at a significance level of 0.01.

"""Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take 
a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval."""
